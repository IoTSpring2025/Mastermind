# %% [markdown]
# #### <b>YOLOv8 Finetuning Script</b>

# %% [markdown]
# <b>Mount Drive</b>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <b>Dependencies</b>

# %%
# !pip install torch ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 10.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# <b>Imports</b>

# %%
import torch
from IPython.display import Image
import os
import random
import shutil
from ultralytics import YOLO
import sys
from roboflow import Roboflow
random.seed(42)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# <b>Download Dataset</b>

# %%
# !rm -rf /content/drive/MyDrive/iot/dataset

# %% [markdown]
# Note: this is taken from generating a new version of the Roboflow dataset

# %%
rf = Roboflow(api_key=os.environ.get("ROBOFLOW_API_KEY", None))
project = rf.workspace().project(os.environ.get("ROBOFLOW_PROJECT", None))
version = project.version(7)
dataset = version.download("yolov8", location="/content/drive/MyDrive/iot/dataset")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/iot/dataset in yolov8:: 100%|██████████| 12560/12560 [01:17<00:00, 162.78it/s]

# %% [markdown]
# <b>Training Script</b>

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/iot/dataset/data.yaml epochs=300 imgsz=640 device=0
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 114MB/s]
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# <b>Upload to Roboflow</b>

# %%
version.deploy("yolov8", "/content/runs/detect/train")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.3.75, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/mastermind-rrqwi/card-detection-zk7wu-3lymd/7
# Share your model with the world at: https://universe.roboflow.com/mastermind-rrqwi/card-detection-zk7wu-3lymd/model/7
