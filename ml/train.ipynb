# %% [markdown]
# # Training
#
# #### Fine-tuning script for YOLOv8 model

# %% [markdown]
# Uncomment if using colab

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Setup
#
# You will need to run `./setup.sh`

# %% [markdown]
# #### Imports

# %%
import torch
from IPython.display import Image
import os
import random
import shutil
import numpy as np

import matplotlib.pyplot as plt
from ultralytics import YOLO

import sys

# only add this if you are using colab
# sys.path.append('/content/drive/MyDrive/iot/yolov8yo')
from yolov8 import utils

random.seed(42)
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 33.2/112.6 GB disk)

# %% [markdown]
# #### Download dataset from Roboflow
#
# Run the following:
#
# `python3 download_dataset.py`
#
# You will need to set the following environment variables: `ROBOFLOW_API_KEY`, `ROBOFLOW_WORKSPACE`, `ROBOFLOW_PROJECT`

# %% [markdown]
# ## Run training script

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/iot/dataset/data.yaml epochs=100 imgsz=640 device=0
# Out:
# Ultralytics 8.3.71 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# ## Upload to Roboflow

# %%
import roboflow
import os

rf = roboflow.Roboflow(api_key=os.environ.get("ROBOFLOW_API_KEY", None))
project = rf.workspace().project(os.environ.get("ROBOFLOW_PROJECT", None))

version = project.version(4)
version.deploy("yolov8", "/content/runs/detect/train3")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.3.71, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/mastermind-rrqwi/card-detection-zk7wu-3lymd/4
# Share your model with the world at: https://universe.roboflow.com/mastermind-rrqwi/card-detection-zk7wu-3lymd/model/4
